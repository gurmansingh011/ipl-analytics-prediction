# %% [markdown]
# # IPL Analytics & Prediction - EDA
#
# This notebook is a starter companion for the Streamlit dashboard. Add the real `matches.csv` and `deliveries.csv` files to `../data/`, then run the cells below.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))

from src.data_preprocessing import IPLDataPreprocessor
from src.analytics import IPLAnalytics

matches, deliveries, demo_mode = IPLDataPreprocessor('../data').load_data()
analytics = IPLAnalytics(matches, deliveries)
demo_mode, matches.shape, deliveries.shape

# %%
analytics.team_summary().head(10)

# %%
analytics.batting_stats().head(10)

# %%
analytics.venue_summary().head(10)
